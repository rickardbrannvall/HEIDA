# %%
#n_parts = 2
#poly_choice = 1

for N_rounds in [20,30,40]:

    scheme = ["plain", "tfhe", "ckks"][2]

    for n_parts in [2,4,8,16]:
        for poly_choice in [0,1]:
            # %run ./nb6_MedMNIST-Copy1.ipynb
    
    
    scheme = ["plain", "tfhe", "ckks"][1]

    for n_parts in [2,4,8,16]:
        for poly_choice in [0,1]:
            # %run ./nb6_MedMNIST.ipynb


    scheme = ["plain", "tfhe", "ckks"][0]

    for n_parts in [8,16]: # [2,4,8,16]:
        for poly_choice in [0]: # [0,1]:
            # %run ./nb6_MedMNIST.ipynb
# Out:
# MedMNIST v2.1.0 @ https://github.com/MedMNIST/MedMNIST/
# scheme: tfhe, n_parts: 2, poly_choice: 0
# n_channels: 3, n_classes: 7
# Using downloaded and verified file: /home/jovyan/.medmnist/dermamnist.npz
# Using downloaded and verified file: /home/jovyan/.medmnist/dermamnist.npz
# Using downloaded and verified file: /home/jovyan/.medmnist/dermamnist.npz
# 7007 7007 3504 7008
# tfhe_256
# Round 1 completed in 80.02413296699524
# Round 3 completed in 81.0069887638092
# Round 5 completed in 79.80177974700928
# Round 7 completed in 79.00558042526245
# Round 9 completed in 80.11198854446411
# Round 11 completed in 78.60209345817566
# Round 13 completed in 76.68935513496399
# Round 15 completed in 78.8002552986145
# Round 17 completed in 80.0051097869873
# Round 19 completed in 80.79206466674805
# Round 20 completed in 78.20680046081543
# MedMNIST v2.1.0 @ https://github.com/MedMNIST/MedMNIST/
# scheme: tfhe, n_parts: 2, poly_choice: 1
# n_channels: 3, n_classes: 7
# ...

# %%
1+1
# Out:
# 2
